# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
print(np.__version__)
# Out:
# 2.3.1

# %%
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.title('Sine Curve')
plt.show()
